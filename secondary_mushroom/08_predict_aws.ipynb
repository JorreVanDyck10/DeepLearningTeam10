# %% [markdown]
# # Secondary Mushroom: Train and tune on AWS
#
# ## Contributors
# - Name: TODO
# - Contribution: TODO
#
# ## Purpose
# The project requires at least one model trained and tuned on AWS. Use this slot for the chosen dataset; mark it not applicable with an explanation for the other dataset. Include the downloaded SageMaker notebook here and record metrics and training settings. Do not store credentials in notebooks.
#
# ## Dataset
# Source: https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset
#
# Predict edible versus poisonous mushrooms using the dataset labels.

# %% [markdown]
# ## Implementation
# TODO: Explain the next code block before adding code. This notebook is a scaffold; no data processing or training has been implemented yet.

# %%
# TODO: Implement the step described above.
