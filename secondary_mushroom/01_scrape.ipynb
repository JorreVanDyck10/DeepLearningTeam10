# %% [markdown]
# # Secondary Mushroom: Download and load data
#
# ## Contributors
# - Name: TODO
# - Contribution: TODO
#
# ## Purpose
# Download the source data with code. Extract archives if needed, assemble the files, and save the original data in data/raw/. Record the source URL and selected files or date range. Do not download or assemble Citi Bike data manually.
#
# ## Dataset
# Source: https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset
#
# Predict edible versus poisonous mushrooms using the dataset labels.

# %% [markdown]
# ## Implementation
# TODO: Explain the next code block before adding code. This notebook is a scaffold; no data processing or training has been implemented yet.

# %%
# TODO: Implement the step described above.
