# %% [markdown]
# # Secondary Mushroom: Final data preparation
#
# ## Contributors
# - Name: TODO
# - Contribution: TODO
#
# ## Purpose
# Summarize the necessary steps from raw data to prepared data, without exploratory graphs. Save prepared data in data/processed/. Define an appropriate train/validation/test split and fit learned preprocessing only on training data to avoid leakage.
#
# ## Dataset
# Source: https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset
#
# Predict edible versus poisonous mushrooms using the dataset labels.

# %% [markdown]
# ## Implementation
# TODO: Explain the next code block before adding code. This notebook is a scaffold; no data processing or training has been implemented yet.

# %%
# TODO: Implement the step described above.
