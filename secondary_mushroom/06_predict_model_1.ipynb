# %% [markdown]
# # Secondary Mushroom: Train and tune additional model 1
#
# ## Contributors
# - Name: TODO
# - Contribution: TODO
#
# ## Purpose
# Choose and justify an additional model. Train and tune it, document the parameters and results, and save metrics and the model. Rename the descriptive part of this filename once the model is chosen, keeping the numeric prefix.
#
# ## Dataset
# Source: https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset
#
# Predict edible versus poisonous mushrooms using the dataset labels.

# %% [markdown]
# ## Implementation
# TODO: Explain the next code block before adding code. This notebook is a scaffold; no data processing or training has been implemented yet.

# %%
# TODO: Implement the step described above.
