# %% [markdown]
# # Secondary Mushroom: Train a quick baseline
#
# ## Contributors
# - Name: TODO
# - Contribution: TODO
#
# ## Purpose
# Build a quick first model, document the prediction target, split, and evaluation metrics, and save results in metrics/. Save the model and its preprocessing in models/ so deployment work can begin.
#
# ## Dataset
# Source: https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset
#
# Predict edible versus poisonous mushrooms using the dataset labels.

# %% [markdown]
# ## Implementation
# TODO: Explain the next code block before adding code. This notebook is a scaffold; no data processing or training has been implemented yet.

# %%
# TODO: Implement the step described above.
